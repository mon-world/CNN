# %%
from PIL import Image
import os, glob, sys
import numpy as np
from sklearn.model_selection import train_test_split # 섞어줌
from keras.utils import np_utils

# %%
# 모델 구성

import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
from tensorflow.keras.layers import concatenate, Input
from keras.models import Model

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
# CNN에서 분류한 데이터를 가져온다.
X_train, X_test, y_train, y_test = np.load('/content/drive/MyDrive/git/4_categorical_100.npy', allow_pickle=True)

# 정규화
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# %%
print(X_train.shape)
print(X_train.shape[0])
print(np.bincount(y_train))
print(np.bincount(y_test))
# Out:
# (9095, 100, 100, 3)
# 9095
# [2750 1484 3175 1686]
# [348 184 299 180]

# %%
# functional 형식

input_img = Input(shape = X_train.shape[1:])
tower_1 = Conv2D(64, (1,1), padding="same", activation="relu")(input_img)
tower_1 = Conv2D(64, (3,3), padding="same", activation="relu")(tower_1)
tower_2 = Conv2D(64, (1,1), padding="same", activation="relu")(input_img)
tower_2 = Conv2D(64, (3,3), padding="same", activation="relu")(tower_2)
tower_2 = Conv2D(64, (3,3), padding="same", activation="relu")(tower_2)
tower_3 = AveragePooling2D((3,3), strides = (1,1), padding = "same")(input_img)
tower_3 = Conv2D(64, (1,1), padding="same", activation="relu")(tower_3)

output1 = keras.layers.concatenate([tower_1, tower_2, tower_3 ], axis = 3)

tower_4 = Conv2D(64, (1,1), padding="same", activation="relu")(output1)
tower_4 = Conv2D(64, (3,3), padding="same", activation="relu")(tower_4)
tower_5 = Conv2D(64, (1,1), padding="same", activation="relu")(output1)
tower_5 = Conv2D(64, (3,3), padding="same", activation="relu")(tower_5)
tower_5 = Conv2D(64, (3,3), padding="same", activation="relu")(tower_5)
tower_6 = AveragePooling2D((3,3), strides = (1,1), padding = "same")(output1)
tower_6 = Conv2D(64, (1,1), padding="same", activation="relu")(tower_6)

output2 = keras.layers.concatenate([tower_4, tower_5, tower_6 ], axis = 3)

tower_7 = Conv2D(64, (1,1), padding="same", activation="relu")(output2)
tower_7 = Conv2D(64, (3,3), padding="same", activation="relu")(tower_7)
tower_8 = Conv2D(64, (1,1), padding="same", activation="relu")(output2)
tower_8 = Conv2D(64, (3,3), padding="same", activation="relu")(tower_8)
tower_8 = Conv2D(64, (3,3), padding="same", activation="relu")(tower_8)
tower_9 = AveragePooling2D((3,3), strides = (1,1), padding = "same")(output2)
tower_9 = Conv2D(64, (1,1), padding="same", activation="relu")(tower_9)

output3 = keras.layers.concatenate([tower_7, tower_8, tower_9 ], axis = 3)

output = GlobalAveragePooling2D()(output3)
out = Dense(4, activation="softmax")(output)

# %%
model = Model(inputs = input_img, outputs = out)
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  conv2d_2 (Conv2D)              (None, 100, 100, 64  256         ['input_1[0][0]']
#                                 )
#
#  conv2d (Conv2D)                (None, 100, 100, 64  256         ['input_1[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 100, 100, 64  36928       ['conv2d_2[0][0]']
#                                 )
#
#  average_pooling2d (AveragePool  (None, 100, 100, 3)  0          ['input_1[0][0]']
#  ing2D)
#
#  conv2d_1 (Conv2D)              (None, 100, 100, 64  36928       ['conv2d[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 100, 100, 64  36928       ['conv2d_3[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 100, 100, 64  256         ['average_pooling2d[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 100, 100, 19  0           ['conv2d_1[0][0]',
#                                 2)                                'conv2d_4[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 100, 100, 64  12352       ['concatenate[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 100, 100, 64  12352       ['concatenate[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 100, 100, 64  36928       ['conv2d_8[0][0]']
#                                 )
#
#  average_pooling2d_1 (AveragePo  (None, 100, 100, 19  0          ['concatenate[0][0]']
#  oling2D)                       2)
#
#  conv2d_7 (Conv2D)              (None, 100, 100, 64  36928       ['conv2d_6[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 100, 100, 64  36928       ['conv2d_9[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 100, 100, 64  12352       ['average_pooling2d_1[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 100, 100, 19  0           ['conv2d_7[0][0]',
#                                 2)                                'conv2d_10[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 100, 100, 64  12352       ['concatenate_1[0][0]']
#                                 )
#
#  conv2d_12 (Conv2D)             (None, 100, 100, 64  12352       ['concatenate_1[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 100, 100, 64  36928       ['conv2d_14[0][0]']
#                                 )
#
#  average_pooling2d_2 (AveragePo  (None, 100, 100, 19  0          ['concatenate_1[0][0]']
#  oling2D)                       2)
#
#  conv2d_13 (Conv2D)             (None, 100, 100, 64  36928       ['conv2d_12[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 100, 100, 64  36928       ['conv2d_15[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 100, 100, 64  12352       ['average_pooling2d_2[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 100, 100, 19  0           ['conv2d_13[0][0]',
#                                 2)                                'conv2d_16[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  global_average_pooling2d (Glob  (None, 192)         0           ['concatenate_2[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 4)            772         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 408,004
# Trainable params: 408,004
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
model.compile(loss = 'sparse_categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
model_dir = '/content/drive/MyDrive/git/model_functional'
if not os.path.exists(model_dir) :
  os.mkdir(model_dir)
model_path = model_dir + "/4_functional_100.model"

checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

history = model.fit(X_train, y_train, callbacks=[checkpoint, early_stopping], batch_size=50, validation_data = (X_test,y_test), epochs = 100)
# Out:
# Epoch 1/100
# 182/182 [==============================] - ETA: 0s - loss: 1.3168 - accuracy: 0.3557
# Epoch 00001: val_loss improved from inf to 1.27604, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 111s 547ms/step - loss: 1.3168 - accuracy: 0.3557 - val_loss: 1.2760 - val_accuracy: 0.4095
# Epoch 2/100
# 182/182 [==============================] - ETA: 0s - loss: 1.2607 - accuracy: 0.3980
# Epoch 00002: val_loss improved from 1.27604 to 1.23124, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 99s 543ms/step - loss: 1.2607 - accuracy: 0.3980 - val_loss: 1.2312 - val_accuracy: 0.4273
# Epoch 3/100
# 182/182 [==============================] - ETA: 0s - loss: 1.2153 - accuracy: 0.4307
# Epoch 00003: val_loss improved from 1.23124 to 1.21764, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 98s 538ms/step - loss: 1.2153 - accuracy: 0.4307 - val_loss: 1.2176 - val_accuracy: 0.4609
# Epoch 4/100
# 182/182 [==============================] - ETA: 0s - loss: 1.1897 - accuracy: 0.4476
# Epoch 00004: val_loss improved from 1.21764 to 1.18300, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 98s 538ms/step - loss: 1.1897 - accuracy: 0.4476 - val_loss: 1.1830 - val_accuracy: 0.4629
# Epoch 5/100
# 182/182 [==============================] - ETA: 0s - loss: 1.1791 - accuracy: 0.4545
# Epoch 00005: val_loss improved from 1.18300 to 1.17212, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 98s 538ms/step - loss: 1.1791 - accuracy: 0.4545 - val_loss: 1.1721 - val_accuracy: 0.4669
# Epoch 6/100
# 182/182 [==============================] - ETA: 0s - loss: 1.1520 - accuracy: 0.4750
# Epoch 00006: val_loss improved from 1.17212 to 1.14981, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 98s 537ms/step - loss: 1.1520 - accuracy: 0.4750 - val_loss: 1.1498 - val_accuracy: 0.5064
# Epoch 7/100
# 182/182 [==============================] - ETA: 0s - loss: 1.1423 - accuracy: 0.4827
# Epoch 00007: val_loss improved from 1.14981 to 1.14322, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 98s 538ms/step - loss: 1.1423 - accuracy: 0.4827 - val_loss: 1.1432 - val_accuracy: 0.4787
# Epoch 8/100
# 182/182 [==============================] - ETA: 0s - loss: 1.0922 - accuracy: 0.5248
# Epoch 00008: val_loss improved from 1.14322 to 1.05266, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 98s 539ms/step - loss: 1.0922 - accuracy: 0.5248 - val_loss: 1.0527 - val_accuracy: 0.5598
# Epoch 9/100
# 182/182 [==============================] - ETA: 0s - loss: 1.0054 - accuracy: 0.5852
# Epoch 00009: val_loss improved from 1.05266 to 1.03399, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 98s 538ms/step - loss: 1.0054 - accuracy: 0.5852 - val_loss: 1.0340 - val_accuracy: 0.5321
# Epoch 10/100
# 182/182 [==============================] - ETA: 0s - loss: 0.9485 - accuracy: 0.6115
# Epoch 00010: val_loss improved from 1.03399 to 0.88979, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 98s 540ms/step - loss: 0.9485 - accuracy: 0.6115 - val_loss: 0.8898 - val_accuracy: 0.6311
# Epoch 11/100
# 182/182 [==============================] - ETA: 0s - loss: 0.8990 - accuracy: 0.6343
# Epoch 00011: val_loss improved from 0.88979 to 0.87168, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 98s 540ms/step - loss: 0.8990 - accuracy: 0.6343 - val_loss: 0.8717 - val_accuracy: 0.6063
# Epoch 12/100
# 182/182 [==============================] - ETA: 0s - loss: 0.8595 - accuracy: 0.6487
# Epoch 00012: val_loss improved from 0.87168 to 0.77926, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 98s 538ms/step - loss: 0.8595 - accuracy: 0.6487 - val_loss: 0.7793 - val_accuracy: 0.6756
# Epoch 13/100
# 182/182 [==============================] - ETA: 0s - loss: 0.8053 - accuracy: 0.6743
# Epoch 00013: val_loss did not improve from 0.77926
# 182/182 [==============================] - 95s 524ms/step - loss: 0.8053 - accuracy: 0.6743 - val_loss: 0.7833 - val_accuracy: 0.6874
# Epoch 14/100
# 182/182 [==============================] - ETA: 0s - loss: 0.7924 - accuracy: 0.6824
# Epoch 00014: val_loss improved from 0.77926 to 0.77812, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 98s 541ms/step - loss: 0.7924 - accuracy: 0.6824 - val_loss: 0.7781 - val_accuracy: 0.6518
# Epoch 15/100
# 182/182 [==============================] - ETA: 0s - loss: 0.7637 - accuracy: 0.6893
# Epoch 00015: val_loss improved from 0.77812 to 0.74652, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 98s 540ms/step - loss: 0.7637 - accuracy: 0.6893 - val_loss: 0.7465 - val_accuracy: 0.6805
# Epoch 16/100
# 182/182 [==============================] - ETA: 0s - loss: 0.7305 - accuracy: 0.6987
# Epoch 00016: val_loss improved from 0.74652 to 0.73289, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 99s 541ms/step - loss: 0.7305 - accuracy: 0.6987 - val_loss: 0.7329 - val_accuracy: 0.7033
# Epoch 17/100
# 182/182 [==============================] - ETA: 0s - loss: 0.7202 - accuracy: 0.7095
# Epoch 00017: val_loss improved from 0.73289 to 0.70013, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 98s 540ms/step - loss: 0.7202 - accuracy: 0.7095 - val_loss: 0.7001 - val_accuracy: 0.7191
# Epoch 18/100
# 182/182 [==============================] - ETA: 0s - loss: 0.6849 - accuracy: 0.7218
# Epoch 00018: val_loss improved from 0.70013 to 0.67913, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 98s 541ms/step - loss: 0.6849 - accuracy: 0.7218 - val_loss: 0.6791 - val_accuracy: 0.7339
# Epoch 19/100
# 182/182 [==============================] - ETA: 0s - loss: 0.6790 - accuracy: 0.7260
# Epoch 00019: val_loss did not improve from 0.67913
# 182/182 [==============================] - 96s 525ms/step - loss: 0.6790 - accuracy: 0.7260 - val_loss: 0.6824 - val_accuracy: 0.7478
# Epoch 20/100
# 182/182 [==============================] - ETA: 0s - loss: 0.6662 - accuracy: 0.7355
# Epoch 00020: val_loss did not improve from 0.67913
# 182/182 [==============================] - 95s 524ms/step - loss: 0.6662 - accuracy: 0.7355 - val_loss: 0.7330 - val_accuracy: 0.6835
# Epoch 21/100
# 182/182 [==============================] - ETA: 0s - loss: 0.6310 - accuracy: 0.7500
# Epoch 00021: val_loss improved from 0.67913 to 0.64568, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 99s 543ms/step - loss: 0.6310 - accuracy: 0.7500 - val_loss: 0.6457 - val_accuracy: 0.7458
# Epoch 22/100
# 182/182 [==============================] - ETA: 0s - loss: 0.6405 - accuracy: 0.7501
# Epoch 00022: val_loss did not improve from 0.64568
# 182/182 [==============================] - 96s 525ms/step - loss: 0.6405 - accuracy: 0.7501 - val_loss: 0.7066 - val_accuracy: 0.7161
# Epoch 23/100
# 182/182 [==============================] - ETA: 0s - loss: 0.6088 - accuracy: 0.7579
# Epoch 00023: val_loss improved from 0.64568 to 0.63822, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 98s 540ms/step - loss: 0.6088 - accuracy: 0.7579 - val_loss: 0.6382 - val_accuracy: 0.7656
# Epoch 24/100
# 182/182 [==============================] - ETA: 0s - loss: 0.6043 - accuracy: 0.7591
# Epoch 00024: val_loss improved from 0.63822 to 0.62397, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 98s 540ms/step - loss: 0.6043 - accuracy: 0.7591 - val_loss: 0.6240 - val_accuracy: 0.7705
# Epoch 25/100
# 182/182 [==============================] - ETA: 0s - loss: 0.5954 - accuracy: 0.7627
# Epoch 00025: val_loss did not improve from 0.62397
# 182/182 [==============================] - 95s 524ms/step - loss: 0.5954 - accuracy: 0.7627 - val_loss: 0.6604 - val_accuracy: 0.7478
# Epoch 26/100
# 182/182 [==============================] - ETA: 0s - loss: 0.5736 - accuracy: 0.7739
# Epoch 00026: val_loss did not improve from 0.62397
# 182/182 [==============================] - 96s 525ms/step - loss: 0.5736 - accuracy: 0.7739 - val_loss: 0.7138 - val_accuracy: 0.7329
# Epoch 27/100
# 182/182 [==============================] - ETA: 0s - loss: 0.5563 - accuracy: 0.7816
# Epoch 00027: val_loss did not improve from 0.62397
# 182/182 [==============================] - 95s 525ms/step - loss: 0.5563 - accuracy: 0.7816 - val_loss: 0.6603 - val_accuracy: 0.7636
# Epoch 28/100
# 182/182 [==============================] - ETA: 0s - loss: 0.5671 - accuracy: 0.7813
# Epoch 00028: val_loss did not improve from 0.62397
# 182/182 [==============================] - 95s 524ms/step - loss: 0.5671 - accuracy: 0.7813 - val_loss: 0.6893 - val_accuracy: 0.7507
# Epoch 29/100
# 182/182 [==============================] - ETA: 0s - loss: 0.5485 - accuracy: 0.7845
# Epoch 00029: val_loss improved from 0.62397 to 0.61414, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 98s 541ms/step - loss: 0.5485 - accuracy: 0.7845 - val_loss: 0.6141 - val_accuracy: 0.7854
# Epoch 30/100
# 182/182 [==============================] - ETA: 0s - loss: 0.5108 - accuracy: 0.8001
# Epoch 00030: val_loss improved from 0.61414 to 0.61381, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 98s 541ms/step - loss: 0.5108 - accuracy: 0.8001 - val_loss: 0.6138 - val_accuracy: 0.7854
# Epoch 31/100
# 182/182 [==============================] - ETA: 0s - loss: 0.5203 - accuracy: 0.7969
# Epoch 00031: val_loss improved from 0.61381 to 0.60785, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 99s 542ms/step - loss: 0.5203 - accuracy: 0.7969 - val_loss: 0.6078 - val_accuracy: 0.7873
# Epoch 32/100
# 182/182 [==============================] - ETA: 0s - loss: 0.4822 - accuracy: 0.8119
# Epoch 00032: val_loss did not improve from 0.60785
# 182/182 [==============================] - 96s 526ms/step - loss: 0.4822 - accuracy: 0.8119 - val_loss: 0.7374 - val_accuracy: 0.7132
# Epoch 33/100
# 182/182 [==============================] - ETA: 0s - loss: 0.4949 - accuracy: 0.8089
# Epoch 00033: val_loss did not improve from 0.60785
# 182/182 [==============================] - 96s 525ms/step - loss: 0.4949 - accuracy: 0.8089 - val_loss: 0.6285 - val_accuracy: 0.7804
# Epoch 34/100
# 182/182 [==============================] - ETA: 0s - loss: 0.4787 - accuracy: 0.8151
# Epoch 00034: val_loss did not improve from 0.60785
# 182/182 [==============================] - 96s 525ms/step - loss: 0.4787 - accuracy: 0.8151 - val_loss: 0.6188 - val_accuracy: 0.7923
# Epoch 35/100
# 182/182 [==============================] - ETA: 0s - loss: 0.4720 - accuracy: 0.8197
# Epoch 00035: val_loss did not improve from 0.60785
# 182/182 [==============================] - 95s 525ms/step - loss: 0.4720 - accuracy: 0.8197 - val_loss: 0.6293 - val_accuracy: 0.7873
# Epoch 36/100
# 182/182 [==============================] - ETA: 0s - loss: 0.4678 - accuracy: 0.8151
# Epoch 00036: val_loss did not improve from 0.60785
# 182/182 [==============================] - 96s 525ms/step - loss: 0.4678 - accuracy: 0.8151 - val_loss: 0.6367 - val_accuracy: 0.7943
# Epoch 37/100
# 182/182 [==============================] - ETA: 0s - loss: 0.4409 - accuracy: 0.8291
# Epoch 00037: val_loss did not improve from 0.60785
# 182/182 [==============================] - 95s 525ms/step - loss: 0.4409 - accuracy: 0.8291 - val_loss: 0.6572 - val_accuracy: 0.7705
# Epoch 38/100
# 182/182 [==============================] - ETA: 0s - loss: 0.4282 - accuracy: 0.8349
# Epoch 00038: val_loss improved from 0.60785 to 0.60560, saving model to /content/drive/MyDrive/git/model_functional/4_functional_100.model
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/git/model_functional/4_functional_100.model/assets
# 182/182 [==============================] - 98s 540ms/step - loss: 0.4282 - accuracy: 0.8349 - val_loss: 0.6056 - val_accuracy: 0.8091
# Epoch 39/100
# 182/182 [==============================] - ETA: 0s - loss: 0.4183 - accuracy: 0.8411
# Epoch 00039: val_loss did not improve from 0.60560
# 182/182 [==============================] - 96s 525ms/step - loss: 0.4183 - accuracy: 0.8411 - val_loss: 0.7135 - val_accuracy: 0.7755
# Epoch 40/100
# 182/182 [==============================] - ETA: 0s - loss: 0.4161 - accuracy: 0.8399
# Epoch 00040: val_loss did not improve from 0.60560
# 182/182 [==============================] - 96s 525ms/step - loss: 0.4161 - accuracy: 0.8399 - val_loss: 0.6059 - val_accuracy: 0.8071
# Epoch 41/100
# 182/182 [==============================] - ETA: 0s - loss: 0.3845 - accuracy: 0.8585
# Epoch 00041: val_loss did not improve from 0.60560
# 182/182 [==============================] - 96s 525ms/step - loss: 0.3845 - accuracy: 0.8585 - val_loss: 0.6952 - val_accuracy: 0.7893
# Epoch 42/100
# 182/182 [==============================] - ETA: 0s - loss: 0.3833 - accuracy: 0.8561
# Epoch 00042: val_loss did not improve from 0.60560
# 182/182 [==============================] - 96s 525ms/step - loss: 0.3833 - accuracy: 0.8561 - val_loss: 0.6267 - val_accuracy: 0.8061
# Epoch 43/100
# 182/182 [==============================] - ETA: 0s - loss: 0.3684 - accuracy: 0.8632
# Epoch 00043: val_loss did not improve from 0.60560
# 182/182 [==============================] - 96s 525ms/step - loss: 0.3684 - accuracy: 0.8632 - val_loss: 0.6745 - val_accuracy: 0.7982
# Epoch 44/100
# 182/182 [==============================] - ETA: 0s - loss: 0.3414 - accuracy: 0.8712
# Epoch 00044: val_loss did not improve from 0.60560
# 182/182 [==============================] - 96s 525ms/step - loss: 0.3414 - accuracy: 0.8712 - val_loss: 0.7838 - val_accuracy: 0.7557
# Epoch 45/100
# 182/182 [==============================] - ETA: 0s - loss: 0.3576 - accuracy: 0.8630
# Epoch 00045: val_loss did not improve from 0.60560
# 182/182 [==============================] - 96s 525ms/step - loss: 0.3576 - accuracy: 0.8630 - val_loss: 0.6789 - val_accuracy: 0.8012
# Epoch 46/100
# 182/182 [==============================] - ETA: 0s - loss: 0.3269 - accuracy: 0.8732
# Epoch 00046: val_loss did not improve from 0.60560
# 182/182 [==============================] - 95s 525ms/step - loss: 0.3269 - accuracy: 0.8732 - val_loss: 0.6864 - val_accuracy: 0.7953
# Epoch 47/100
# 182/182 [==============================] - ETA: 0s - loss: 0.3349 - accuracy: 0.8730
# Epoch 00047: val_loss did not improve from 0.60560
# 182/182 [==============================] - 95s 525ms/step - loss: 0.3349 - accuracy: 0.8730 - val_loss: 0.7120 - val_accuracy: 0.8032
# Epoch 48/100
# 182/182 [==============================] - ETA: 0s - loss: 0.3360 - accuracy: 0.8715
# Epoch 00048: val_loss did not improve from 0.60560
# 182/182 [==============================] - 96s 525ms/step - loss: 0.3360 - accuracy: 0.8715 - val_loss: 0.7862 - val_accuracy: 0.7873

# %%
# 정확도와 loss 차트 그리기
# %matplotlib inline

import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

# history의 train과 test의 정확도와 loss를 각각 가져온다.
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # 에포크

# 그래프로 표시
plt.plot(epochs, acc, 'r', "acc")
plt.plot(epochs, val_acc, 'b', "val_acc")
plt.plot(epochs, loss, 'y', "loss")
plt.plot(epochs, val_loss, 'g', "val_loss")
plt.legend(['acc','val_acc','loss','val_loss'], loc = 'upper left')

plt.title('Training and validation : accuracy and loss')
plt.figure()
